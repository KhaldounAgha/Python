# %% [markdown]
# # Matplotlib
# Read the tutorials: "Basic Usage" and "Pyplot Tutorial" in the link: https://matplotlib.org/stable/tutorials/index.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
print ("""In Matplotlib, we can plot in two ways: the "pyplot" interface or the "object-oriented" interface.
The "object-oriented" interface is the recommended approach nowadays 
because it gives more control and flexibility over the plots we creat.""")
# Out:
# In Matplotlib, we can plot in two ways: the "pyplot" interface or the "object-oriented" interface.
# The "object-oriented" interface is the recommended approach nowadays
# because it gives more control and flexibility over the plots we creat.

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
print ("""Figures and axes are structural elements of the plots we create.
Figure: Is a window where you can place plots and it's a container for the elements of the plots.
Axes: The plotting areas within a figure. The graphs or charts where data is displayed. A figure can contain one or more axes.
Axis: A line with numbers, ticks and labels. It represents a range (interval) for a specific dimension. Exemple: horizontal x-axis and the vertical y-axis.
Artist: Everything we see on a plot is an artist including figures, axes, lines, labels, shapes etc. """)
# Out:
# Figures and axes are structural elements of the plots we create.
# Figure: Is a window where you can place plots and it's a container for the elements of the plots.
# Axes: The plotting areas within a figure. The graphs or charts where data is displayed. A figure can contain one or more axes.
# Axis: A line with numbers, ticks and labels. It represents a range (interval) for a specific dimension. Exemple: horizontal x-axis and the vertical y-axis.
# Artist: Everything we see on a plot is an artist including figures, axes, lines, labels, shapes etc.

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
print (""" Common input data types: NumPy Arrays, Python Lists, Pandas DataFrames and Tuples""")
# Out:
#  Common input data types: NumPy Arrays, Python Lists, Pandas DataFrames and Tuples

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
x = np.linspace (-4, 4, 200)
y = x**2
plt.plot(x, y, "r--")
plt.title ("Plot Of Function [f(x) = x**2]")
plt.xlabel("X variable")
plt.ylabel(" Y variable [y = x**2]")
plt.show()

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
ax1.scatter(x, y)
ax2.bar(names, values)
plt.show()
